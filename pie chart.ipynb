# %%
import matplotlib.pyplot as plt
import pandas as pd
data2 = pd.read_csv(r"C:\Users\SHOBHIT KUMAR\OneDrive\Desktop\xyz.csv")
df = pd.DataFrame(data2)
plt.pie(df['marks'], labels=df['Subjact'],autopct="%1.1f%%")
plt.title("Student XYZ Marks Distribution")
plt.show(True)

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv(r"C:\Users\SHOBHIT KUMAR\OneDrive\Desktop\1-Sem Result.csv")
df = pd.DataFrame(data)
plt.pie(df['Marks'],labels=df['Subjact'],autopct="%1.1f%%")
plt.title("My 1st Semesster Exam Score Card")
plt.show(True)
