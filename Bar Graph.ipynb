# %%
import matplotlib.pyplot as plt
student = ["ramesh","suresh","vikash","rahul","ram"]
marks = [55,47,78,98,25]
plt.figure(figsize =(8,8))
plt.bar(student,marks,color = "red")
plt.title("Marks Student Score in class ")
plt.xlabel("Name of Student")
plt.ylabel("Marks")
plt.show()
